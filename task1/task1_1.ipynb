# %%
import numpy as np
import matplotlib.pyplot as plt
low = 0
high = 1
N = 1000
x = np.random.uniform(low, high, N)
plt.plot(x, '.', markersize=3)
plt.xlabel("Sample index", fontsize=14)
plt.ylabel("Value", fontsize=14)
plt.title("Uniformly Distributed Samples", fontsize=14)
plt.show()

# %%
theoretical_mean = (low + high)/2
sample_mean = x.sum()/N
print("Theoretical Mean: ", theoretical_mean)
print("Sample Mean: ", sample_mean)
print("Mean error: ", theoretical_mean - sample_mean)
# Out:
# Theoretical Mean:  0.5
# Sample Mean:  0.5066419418582917
# Mean error:  -0.0066419418582917

# %% [markdown]
# Sample mean is a good estimator of the theoretical mean, as all samples come from the same underlying time invariant distribution.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
# theoretical_SD = (high-low)/np.sqrt(12)
theoretical_SD = np.sqrt(np.mean(((x - 0.5) ** 2)))
sample_SD = np.sqrt(1/(N-1) * (np.sum(np.square(x-sample_mean))))
print("Theoretical SD: ", theoretical_SD)
print("Sample SD: ", sample_SD)
print("SD error: ", sample_SD - theoretical_SD)
# Out:
# Theoretical SD:  0.290360919377917
# Sample SD:  0.2904301943809363
# SD error:  6.92750030192868e-05

# %% [markdown]
# Sample estimate of standard deviation is also accurate due to the high number of samples used.

# %%
M = 10
N = 1000
x = np.random.uniform(low, high, size=(N, M))
theoretical_mean = (low + high)/2
sample_mean = np.sum(x, axis=0)/N
# theoretical_SD = (high-low)/np.sqrt(12)
theoretical_SD = np.sqrt(np.mean(((x - 0.5) ** 2)))
sample_SD = np.sqrt(1/(N-1) * (np.sum(np.square(x-sample_mean), axis=0)))
plt.plot(sample_mean, '.', markersize=3)
plt.axhline(theoretical_mean, color='red', linestyle='--', linewidth=1)
plt.xlabel("Realisation Index", fontsize=14)
plt.ylabel("Sample mean", fontsize=14)
plt.title("Sample means over 10 realisations", fontsize=14)
plt.show()

plt.plot(sample_SD, '.', markersize=3)
plt.axhline(theoretical_SD, color='red', linestyle='--', linewidth=1)
plt.xlabel("Realisation Index", fontsize=14)
plt.ylabel("Sample standard deviation", fontsize=14)
plt.title("Sample standard deviation over 10 realisations", fontsize=14)
plt.show()

# %% [markdown]
# Comment about their bias here.

# %%
x_hist = np.random.uniform(low, high, N*100)
theoretical_pdf = 1
plt.hist(x_hist, bins=50, density=True, color='blue', edgecolor='black')
plt.axhline(theoretical_pdf, color='red', linestyle='--', linewidth=1)
plt.xlabel('Value', fontsize=14)
plt.ylabel('pdf', fontsize=14)
plt.title('Theoretical and Estimate pdf', fontsize=14)
plt.show()

# %% [markdown]
# The estimate appears to converge as the number of generated samples increases (law of large numbers). As number of bins increases, we get a less smooth estimate pdf with more variance.

# %% [markdown]
# Standard Normal Distribution:

# %%
N = 1000
x = np.random.randn(N)
plt.plot(x, '.', markersize=3)
plt.xlabel("Sample index", fontsize=14)
plt.ylabel("Value", fontsize=14)
plt.title("Uniformly Distributed Samples", fontsize=14)
plt.show()

# %%
theoretical_mean = 0
sample_mean = x.sum()/N
print("Theoretical Mean: ", theoretical_mean)
print("Sample Mean: ", sample_mean)
print("Mean error: ", theoretical_mean - sample_mean)
# Out:
# Theoretical Mean:  0
# Sample Mean:  -0.03665830625755896
# Mean error:  0.03665830625755896

# %%
theoretical_SD = 1
sample_SD = np.sqrt(1/(N-1) * (np.sum(np.square(x-sample_mean))))
print("Theoretical SD: ", theoretical_SD)
print("Sample SD: ", sample_SD)
print("SD error: ", sample_SD - theoretical_SD)
# Out:
# Theoretical SD:  1
# Sample SD:  1.0064733791052687
# SD error:  0.006473379105268684

# %%
import random as rng
M = 10
N = 1000
rng = np.random.default_rng()
x = rng.standard_normal((N, M))
theoretical_mean = 0
sample_mean = np.sum(x, axis=0)/N
theoretical_SD = 1
sample_SD = np.sqrt(1/(N-1) * (np.sum(np.square(x-sample_mean), axis=0)))
plt.plot(sample_mean, '.', markersize=3)
plt.axhline(theoretical_mean, color='red', linestyle='--', linewidth=1)
plt.xlabel("Realisation Index", fontsize=14)
plt.ylabel("Sample mean", fontsize=14)
plt.title("Sample means over 10 realisations", fontsize=14)
plt.show()

plt.plot(sample_SD, '.', markersize=3)
plt.axhline(theoretical_SD, color='red', linestyle='--', linewidth=1)
plt.xlabel("Realisation Index", fontsize=14)
plt.ylabel("Sample standard deviation", fontsize=14)
plt.title("Sample standard deviation over 10 realisations", fontsize=14)
plt.show()

# %%
N = 1000
x_hist = np.random.randn(N)
x = np.linspace(-4, 4, 1000)
theoretical_pdf = (1 / np.sqrt(2 * np.pi)) * np.exp(-0.5 * x**2)
plt.hist(x_hist, bins=50, density=True, color='blue', edgecolor='black')
plt.plot(x, theoretical_pdf, 'r--', linewidth=2)
plt.xlabel('Value', fontsize=14)
plt.ylabel('pdf', fontsize=14)
plt.title('Theoretical and Estimate pdf', fontsize=14)
plt.show()
